# %%
# !pip install ultralytics -q # installation du bibliothèque ultralytics

# %%
from ultralytics import YOLO # importation du module YPLO

# %%
model = YOLO("yolov8m.pt") # ajoutant pre-trained model

# %%
model.train(data =  "data.yaml", epochs = 5) # entrainant le modéle sur notre dataSet
# Out:
# Ultralytics YOLOv8.0.107 🚀 Python-3.10.6 torch-2.0.1+cu117 CPU
# ...

# %%
infer = YOLO("runs/detect/train5/weights/best.pt")

# %%
infer.predict("test/images", save=True, save_txt =True) # test du modéle
# Out:
# image 1/31 /home/mahjouba/speed-bump-ppp/speed_bumps_data2/test/images/6_jpg.rf.9ca48d52c592bada5e71e3c8d6ac8b4b.jpg: 640x640 1 NonMarked Bump, 468.6ms
# image 2/31 /home/mahjouba/speed-bump-ppp/speed_bumps_data2/test/images/Image00040_jpg.rf.e5b0e2b6d889613b55420f8c58e899c7.jpg: 640x640 2 Marked Bumps, 439.5ms
# image 3/31 /home/mahjouba/speed-bump-ppp/speed_bumps_data2/test/images/Image00044_jpg.rf.cae22939b3ae22e7819e29d76b4e0e43.jpg: 640x640 1 Marked Bump, 599.7ms
# image 4/31 /home/mahjouba/speed-bump-ppp/speed_bumps_data2/test/images/Image00077_jpg.rf.2f41882b4ee9ae4c096e75ee3ad76d3f.jpg: 640x640 1 Marked Bump, 461.1ms
# image 5/31 /home/mahjouba/speed-bump-ppp/speed_bumps_data2/test/images/Image00086_jpg.rf.315c62d77eac72a267ab7cbb992b96c9.jpg: 640x640 1 Marked Bump, 436.1ms
# image 6/31 /home/mahjouba/speed-bump-ppp/speed_bumps_data2/test/images/Speed-Bumpimg_114_jpg.rf.10f1f189fe4636eec3e87268768beb65.jpg: 640x640 2 Marked Bumps, 334.5ms
# ...

# %%
# !yolo export model="runs/detect/train5/weights/best.pt" format=tflie  # convertissant le modéle en tonserflow lite
# Out:
# Traceback (most recent call last):
#   File "/home/mahjouba/.local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/home/mahjouba/.local/lib/python3.10/site-packages/ultralytics/yolo/cfg/__init__.py", line 394, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#   File "/home/mahjouba/.local/lib/python3.10/site-packages/ultralytics/yolo/engine/model.py", line 340, in export
#     return Exporter(overrides=args, _callbacks=self.callbacks)(model=self.model)
#   File "/home/mahjouba/.local/lib/python3.10/site-packages/ultralytics/yolo/engine/exporter.py", line 142, in __init__
#     callbacks.add_integration_callbacks(self)
#   File "/home/mahjouba/.local/lib/python3.10/site-packages/ultralytics/yolo/utils/callbacks/base.py", line 205, in add_integration_callbacks
#     from .tensorboard import callbacks as tensorboard_cb
# ...
